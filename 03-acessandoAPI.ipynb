# %% [markdown]
# ## 3) Acessando APIs com Python

# %% [markdown]
# Para essa atividade queremos que você utilize essa API. Nela você encontrará resultados de
# partidas de diversos esportes. Queremos que você utilize o endpoint de *scores* para buscar
# determinadas informações do sport soccer_brazil_campeonato na resposta da API e salvar
# numa tabela chamada *partidas_brasileirao_serie_a_2023* contendo as seguintes colunas:
# - datahora_partida
# - data_partida
# - time_casa
# - time_fora
# - gols_time_casa
# - gols_time_fora
#
# Obs: trazer apenas os resultados do ano de 2023.
# Essas informações devem ser salvas num banco local em MYSQL, o mesmo utilizado para
# as outras atividades.

# %%
import requests

url = "https://odds.p.rapidapi.com/v4/sports/soccer_brazil_campeonato/scores"

querystring = {"daysFrom":"3"}

headers = {
	"X-RapidAPI-Key": "CHAVE DA API OCULTADO POR QUESTOES DE SEGURANÇA",
	"X-RapidAPI-Host": "odds.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# [{'id': '3370a74110945d9d530d3f3fcb7a9290', 'sport_key': 'soccer_brazil_campeonato', 'sport_title': 'Brazil Série A', 'commence_time': '2023-07-16T19:00:09Z', 'completed': True, 'home_team': 'Fluminense', 'away_team': 'Flamengo', 'scores': [{'name': 'Fluminense', 'score': '0'}, {'name': 'Flamengo', 'score': '0'}], 'last_update': '2023-07-17T04:50:47Z'}, {'id': '929d86103fe49899d2d8a23bf142f358', 'sport_key': 'soccer_brazil_campeonato', 'sport_title': 'Brazil Série A', 'commence_time': '2023-07-16T19:00:38Z', 'completed': True, 'home_team': 'Fortaleza', 'away_team': 'Cuiabá', 'scores': [{'name': 'Fortaleza', 'score': '0'}, {'name': 'Cuiabá', 'score': '1'}], 'last_update': '2023-07-17T04:50:47Z'}, {'id': '9a52f88c8435569197250fe6b5434ba5', 'sport_key': 'soccer_brazil_campeonato', 'sport_title': 'Brazil Série A', 'commence_time': '2023-07-16T19:00:50Z', 'completed': True, 'home_team': 'Sao Paulo', 'away_team': 'Santos', 'scores': [{'name': 'Sao Paulo', 'score': '4'}, {'name': 'Santos', 
# ...

# %%
jsondata = response.json()

# %%
import pandas as pd

df = pd.DataFrame(jsondata)
df.head()
# Out:
#                                  id                 sport_key     sport_title  \
# 0  3370a74110945d9d530d3f3fcb7a9290  soccer_brazil_campeonato  Brazil Série A
# 1  929d86103fe49899d2d8a23bf142f358  soccer_brazil_campeonato  Brazil Série A
# 2  9a52f88c8435569197250fe6b5434ba5  soccer_brazil_campeonato  Brazil Série A
# 3  9ebb56a1a2d944b326383c4e2e682baf  soccer_brazil_campeonato  Brazil Série A
# 4  58778f76292dcbbe502ffab3e3d204c5  soccer_brazil_campeonato  Brazil Série A
#
#           commence_time  completed            home_team  away_team  \
# 0  2023-07-16T19:00:09Z       True           Fluminense   Flamengo
# 1  2023-07-16T19:00:38Z       True            Fortaleza     Cuiabá
# 2  2023-07-16T19:00:50Z       True            Sao Paulo     Santos
# 3  2023-07-16T21:29:59Z       True        Internacional  Palmeiras
# 4  2023-07-16T21:30:00Z       True  Atletico Paranaense      Bahia
#
#                                                                              scores  \
# ...

# %%
# pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_colwidth', None)

# %%
df["scores"].head(10)
# Out:
# 0          [{'name': 'Fluminense', 'score': '0'}, {'name': 'Flamengo', 'score': '0'}]
# 1             [{'name': 'Fortaleza', 'score': '0'}, {'name': 'Cuiabá', 'score': '1'}]
# 2             [{'name': 'Sao Paulo', 'score': '4'}, {'name': 'Santos', 'score': '1'}]
# 3      [{'name': 'Internacional', 'score': '0'}, {'name': 'Palmeiras', 'score': '0'}]
# 4    [{'name': 'Atletico Paranaense', 'score': '2'}, {'name': 'Bahia', 'score': '0'}]
# 5       [{'name': 'Goiás', 'score': '0'}, {'name': 'Atletico Mineiro', 'score': '0'}]
# 6                                                                                None
# 7                                                                                None
# 8                                                                                None
# 9                                                                                None
# Name: scores, dtype: object

# %%
partida = pd.json_normalize(df['scores'])

# %%
df_select = df[["commence_time","home_team","away_team","scores" ]]
df_select.head(5)
# Out:
#           commence_time            home_team  away_team  \
# 0  2023-07-16T19:00:09Z           Fluminense   Flamengo
# 1  2023-07-16T19:00:38Z            Fortaleza     Cuiabá
# 2  2023-07-16T19:00:50Z            Sao Paulo     Santos
# 3  2023-07-16T21:29:59Z        Internacional  Palmeiras
# 4  2023-07-16T21:30:00Z  Atletico Paranaense      Bahia
#
#                                                                              scores
# 0        [{'name': 'Fluminense', 'score': '0'}, {'name': 'Flamengo', 'score': '0'}]
# 1           [{'name': 'Fortaleza', 'score': '0'}, {'name': 'Cuiabá', 'score': '1'}]
# 2           [{'name': 'Sao Paulo', 'score': '4'}, {'name': 'Santos', 'score': '1'}]
# 3    [{'name': 'Internacional', 'score': '0'}, {'name': 'Palmeiras', 'score': '0'}]
# 4  [{'name': 'Atletico Paranaense', 'score': '2'}, {'name': 'Bahia', 'score': '0'}]

# %%
df_select['DataJogo'] = pd.to_datetime(df_select['commence_time']).dt.date
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_14452\887847970.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['DataJogo'] = pd.to_datetime(df_select['commence_time']).dt.date

# %%
b = pd.json_normalize(df_select['scores'])

# %%
b1 = pd.DataFrame(b[0]).head(5)

# %%
names = b1.apply(lambda x: x[0]['name'])
names.head()
# Out:
# 0    Fluminense
# dtype: object

# %%
df_select['Casa'] =  b[0]
df_select
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_14452\1572624795.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['Casa'] =  b[0]
#            commence_time            home_team            away_team  \
# 0   2023-07-16T19:00:09Z           Fluminense             Flamengo
# 1   2023-07-16T19:00:38Z            Fortaleza               Cuiabá
# 2   2023-07-16T19:00:50Z            Sao Paulo               Santos
# 3   2023-07-16T21:29:59Z        Internacional            Palmeiras
# 4   2023-07-16T21:30:00Z  Atletico Paranaense                Bahia
# 5   2023-07-17T22:59:46Z                Goiás     Atletico Mineiro
# 6   2023-07-22T19:00:00Z             Flamengo      América Mineiro
# ...

# %%
df_select['Fora'] =  b[1]
df_select
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_14452\3633255341.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['Fora'] =  b[1]
#            commence_time            home_team            away_team  \
# 0   2023-07-16T19:00:09Z           Fluminense             Flamengo
# 1   2023-07-16T19:00:38Z            Fortaleza               Cuiabá
# 2   2023-07-16T19:00:50Z            Sao Paulo               Santos
# 3   2023-07-16T21:29:59Z        Internacional            Palmeiras
# 4   2023-07-16T21:30:00Z  Atletico Paranaense                Bahia
# 5   2023-07-17T22:59:46Z                Goiás     Atletico Mineiro
# 6   2023-07-22T19:00:00Z             Flamengo      América Mineiro
# ...

# %%
df_select['time_casa'] = pd.json_normalize(df_select['Casa']).get('name')
df_select['gols_time_casa'] = pd.json_normalize(df_select['Casa']).get('score')
df_select['time_fora'] = pd.json_normalize(df_select['Fora']).get('name')
df_select['gols_time_fora'] = pd.json_normalize(df_select['Fora']).get('score')
# Out:
# C:\Users\Bruno\AppData\Local\Temp\ipykernel_14452\1799368546.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_select['time_casa'] = pd.json_normalize(df_select['Casa']).get('name')

# %%
df_select.head(5)
# Out:
#           commence_time            home_team  away_team  \
# 0  2023-07-16T19:00:09Z           Fluminense   Flamengo
# 1  2023-07-16T19:00:38Z            Fortaleza     Cuiabá
# 2  2023-07-16T19:00:50Z            Sao Paulo     Santos
# 3  2023-07-16T21:29:59Z        Internacional  Palmeiras
# 4  2023-07-16T21:30:00Z  Atletico Paranaense      Bahia
#
#                                                                              scores  \
# 0        [{'name': 'Fluminense', 'score': '0'}, {'name': 'Flamengo', 'score': '0'}]
# 1           [{'name': 'Fortaleza', 'score': '0'}, {'name': 'Cuiabá', 'score': '1'}]
# 2           [{'name': 'Sao Paulo', 'score': '4'}, {'name': 'Santos', 'score': '1'}]
# 3    [{'name': 'Internacional', 'score': '0'}, {'name': 'Palmeiras', 'score': '0'}]
# 4  [{'name': 'Atletico Paranaense', 'score': '2'}, {'name': 'Bahia', 'score': '0'}]
#
#      DataJogo                                           Casa  \
# ...

# %%
df_select.drop(['scores', 'Casa', 'Fora'], axis=1)
# Out:
#            commence_time            home_team            away_team  \
# 0   2023-07-16T19:00:09Z           Fluminense             Flamengo
# 1   2023-07-16T19:00:38Z            Fortaleza               Cuiabá
# 2   2023-07-16T19:00:50Z            Sao Paulo               Santos
# 3   2023-07-16T21:29:59Z        Internacional            Palmeiras
# 4   2023-07-16T21:30:00Z  Atletico Paranaense                Bahia
# 5   2023-07-17T22:59:46Z                Goiás     Atletico Mineiro
# 6   2023-07-22T19:00:00Z             Flamengo      América Mineiro
# 7   2023-07-22T19:00:00Z            Palmeiras            Fortaleza
# 8   2023-07-22T21:30:00Z                Bahia          Corinthians
# 9   2023-07-22T21:30:00Z               Cuiabá            Sao Paulo
# 10  2023-07-23T00:00:00Z               Gremio     Atletico Mineiro
# 11  2023-07-23T19:00:00Z               Santos             Botafogo
# 12  2023-07-23T19:00:00Z        Bragantino-SP        Internacional
# ...

# %%
df_select = df_select.drop(['scores', 'Casa', 'Fora','time_casa','time_fora' ], axis=1)

# %%
df_select.rename({"commence_time": "datahora_partida", "home_team":"time_casa", "away_team":"time_fora" }, axis=1, inplace=True)

# %%
df_select
# Out:
#         datahora_partida            time_casa            time_fora  \
# 0   2023-07-16T19:00:09Z           Fluminense             Flamengo
# 1   2023-07-16T19:00:38Z            Fortaleza               Cuiabá
# 2   2023-07-16T19:00:50Z            Sao Paulo               Santos
# 3   2023-07-16T21:29:59Z        Internacional            Palmeiras
# 4   2023-07-16T21:30:00Z  Atletico Paranaense                Bahia
# 5   2023-07-17T22:59:46Z                Goiás     Atletico Mineiro
# 6   2023-07-22T19:00:00Z             Flamengo      América Mineiro
# 7   2023-07-22T19:00:00Z            Palmeiras            Fortaleza
# 8   2023-07-22T21:30:00Z                Bahia          Corinthians
# 9   2023-07-22T21:30:00Z               Cuiabá            Sao Paulo
# 10  2023-07-23T00:00:00Z               Gremio     Atletico Mineiro
# 11  2023-07-23T19:00:00Z               Santos             Botafogo
# 12  2023-07-23T19:00:00Z        Bragantino-SP        Internacional
# ...

# %% [markdown]
# ## Gravando as informações no MYSQL

# %%
def df_to_mysql(dataframe, tabela, usuario_bd, senha_bd, database_bd):
    '''
    Grava as informacoes do DataFrame em uma tabela do MySQL
    
    Args:
    database: Dataframe do Pandas para gravar na tabela
    tabela: Nome da tabela a ser criada para gravar os dados do dataframe
    usuario_bd: usuario do MySQL
    senha_bd: Senha do MySQL
    database_bd: Database no formato "servidor/schema" Exempo: localhost/teste
    ''' 
    from sqlalchemy import create_engine
    # my_conn = create_engine("mysql+mysqldb://root:NN8eD2Ae@localhost/teste")
    my_conn = create_engine(f"mysql+mysqldb://{usuario_bd}:{senha_bd}@{database_bd}")

    dataframe.to_sql(con=my_conn, name=tabela, if_exists='append', index=False)

# %%
# gravando DataFrame para o MYSQL 
df_to_mysql(df_select, 'h2_resultado_api', 'USUARIO_MYSQL', 'SENHA_MYSQL','localhost/h2') # ocultado por questoes de segurança
